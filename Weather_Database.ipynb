# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
 # Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c81d73dbe371b3be20cb667ce7cf2b7a

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | havelock
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | hami
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | vila franca do campo
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | acarau
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | nouadhibou
# Processing Record 15 of Set 1 | la ronge
# Processing Record 16 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 1 | phan thiet
# Processing Record 18 of Set 1 | andenes
# Processing Record 19 of Set 1 | kendari
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | ostrovnoy
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | sorong
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | eureka
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | kirensk
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 1 | marathon
# Processing Record 43 of Set 1 | okhotsk
# Processing Record 44 of Set 1 | roald
# Processing Record 45 of Set 1 | balykshi
# Processing Record 46 of Set 1 | arona
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | tasiilaq
# Processing Record 49 of Set 1 | houston
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | los llanos de aridane
# Processing Record 2 of Set 2 | penzance
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | hearst
# Processing Record 5 of Set 2 | kahta
# Processing Record 6 of Set 2 | kavaratti
# Processing Record 7 of Set 2 | makung
# City not found. Skipping...
# Processing Record 8 of Set 2 | diego de almagro
# Processing Record 9 of Set 2 | karratha
# Processing Record 10 of Set 2 | nago
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | chernyshevskiy
# Processing Record 13 of Set 2 | khartoum
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | caravelas
# Processing Record 16 of Set 2 | punta alta
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | komsomolskiy
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | nemuro
# Processing Record 23 of Set 2 | port shepstone
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | portland
# Processing Record 28 of Set 2 | demir kapija
# Processing Record 29 of Set 2 | kranjska gora
# Processing Record 30 of Set 2 | usinsk
# Processing Record 31 of Set 2 | kieta
# Processing Record 32 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 2 | haines junction
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | natal
# Processing Record 36 of Set 2 | pontal do parana
# Processing Record 37 of Set 2 | port blair
# Processing Record 38 of Set 2 | pacific grove
# Processing Record 39 of Set 2 | urumqi
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | cayenne
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | nelson bay
# Processing Record 45 of Set 2 | anchorage
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | pascagoula
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | port-gentil
# Processing Record 50 of Set 2 | barcelos
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | kaseda
# Processing Record 3 of Set 3 | wajir
# Processing Record 4 of Set 3 | husavik
# Processing Record 5 of Set 3 | cape coast
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | darnah
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | billings
# Processing Record 14 of Set 3 | santa rosa
# Processing Record 15 of Set 3 | kasongo-lunda
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | kulhudhuffushi
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | avera
# Processing Record 21 of Set 3 | codrington
# Processing Record 22 of Set 3 | linqiong
# Processing Record 23 of Set 3 | gazli
# Processing Record 24 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 3 | saint-joseph
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | nikologory
# Processing Record 28 of Set 3 | juneau
# Processing Record 29 of Set 3 | gonen
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | kristiinankaupunki
# Processing Record 32 of Set 3 | tuburan
# Processing Record 33 of Set 3 | yurimaguas
# Processing Record 34 of Set 3 | gat
# Processing Record 35 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 3 | adre
# Processing Record 37 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | paamiut
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | thinadhoo
# Processing Record 43 of Set 3 | totness
# Processing Record 44 of Set 3 | godda
# Processing Record 45 of Set 3 | fukue
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | baker city
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | abatskoye
# Processing Record 50 of Set 3 | coromandel
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | poum
# Processing Record 3 of Set 4 | guerrero negro
# Processing Record 4 of Set 4 | luanda
# Processing Record 5 of Set 4 | abapo
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | mercedes
# Processing Record 8 of Set 4 | port moresby
# Processing Record 9 of Set 4 | menongue
# Processing Record 10 of Set 4 | dalianwan
# Processing Record 11 of Set 4 | bathsheba
# Processing Record 12 of Set 4 | bubaque
# Processing Record 13 of Set 4 | monrovia
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | boali
# Processing Record 16 of Set 4 | heihe
# Processing Record 17 of Set 4 | galesong
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | hirara
# Processing Record 20 of Set 4 | adrar
# Processing Record 21 of Set 4 | nishihara
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | kattivakkam
# Processing Record 24 of Set 4 | tautira
# Processing Record 25 of Set 4 | antofagasta
# Processing Record 26 of Set 4 | acajutla
# Processing Record 27 of Set 4 | naze
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | te anau
# Processing Record 30 of Set 4 | luau
# Processing Record 31 of Set 4 | kondinskoye
# Processing Record 32 of Set 4 | vostok
# Processing Record 33 of Set 4 | paris
# Processing Record 34 of Set 4 | zilair
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | nome
# Processing Record 37 of Set 4 | sao jose da coroa grande
# Processing Record 38 of Set 4 | ponta do sol
# Processing Record 39 of Set 4 | george
# Processing Record 40 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | saint-pierre
# Processing Record 43 of Set 4 | arraial do cabo
# Processing Record 44 of Set 4 | two hills
# Processing Record 45 of Set 4 | meadow lake
# Processing Record 46 of Set 4 | markova
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | sitka
# Processing Record 50 of Set 4 | zhigansk
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | ust-tsilma
# Processing Record 3 of Set 5 | colares
# Processing Record 4 of Set 5 | bambanglipuro
# Processing Record 5 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 5 | lukiv
# Processing Record 7 of Set 5 | bilma
# Processing Record 8 of Set 5 | lompoc
# Processing Record 9 of Set 5 | caruray
# Processing Record 10 of Set 5 | mehriz
# Processing Record 11 of Set 5 | san quintin
# Processing Record 12 of Set 5 | provideniya
# Processing Record 13 of Set 5 | kuruman
# Processing Record 14 of Set 5 | atambua
# Processing Record 15 of Set 5 | gondar
# Processing Record 16 of Set 5 | yumen
# Processing Record 17 of Set 5 | karwar
# Processing Record 18 of Set 5 | baruun-urt
# Processing Record 19 of Set 5 | bilibino
# Processing Record 20 of Set 5 | yangambi
# Processing Record 21 of Set 5 | marsabit
# Processing Record 22 of Set 5 | warmbad
# Processing Record 23 of Set 5 | saint-georges
# Processing Record 24 of Set 5 | zverinogolovskoye
# Processing Record 25 of Set 5 | copiapo
# Processing Record 26 of Set 5 | ascension
# Processing Record 27 of Set 5 | rosemount
# Processing Record 28 of Set 5 | pompeia
# Processing Record 29 of Set 5 | daru
# Processing Record 30 of Set 5 | rio gallegos
# Processing Record 31 of Set 5 | lagoa
# Processing Record 32 of Set 5 | rawson
# Processing Record 33 of Set 5 | erdenet
# Processing Record 34 of Set 5 | luneville
# Processing Record 35 of Set 5 | skelleftea
# Processing Record 36 of Set 5 | batagay-alyta
# Processing Record 37 of Set 5 | meulaboh
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | pevek
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | primero de enero
# Processing Record 42 of Set 5 | aykhal
# Processing Record 43 of Set 5 | nevers
# Processing Record 44 of Set 5 | garwa
# Processing Record 45 of Set 5 | neuquen
# Processing Record 46 of Set 5 | kpandae
# Processing Record 47 of Set 5 | ust-maya
# Processing Record 48 of Set 5 | konskie
# Processing Record 49 of Set 5 | chervonohryhorivka
# Processing Record 50 of Set 5 | kahului
# Processing Record 1 of Set 6 | el bagre
# Processing Record 2 of Set 6 | scarborough
# Processing Record 3 of Set 6 | berlevag
# Processing Record 4 of Set 6 | nicoya
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | jishou
# Processing Record 7 of Set 6 | sao felix do xingu
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | show low
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | east london
# Processing Record 12 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 6 | sweetwater
# Processing Record 14 of Set 6 | mangan
# Processing Record 15 of Set 6 | ambon
# Processing Record 16 of Set 6 | ancud
# Processing Record 17 of Set 6 | bose
# Processing Record 18 of Set 6 | ulladulla
# Processing Record 19 of Set 6 | bathurst
# Processing Record 20 of Set 6 | moron
# Processing Record 21 of Set 6 | faya
# Processing Record 22 of Set 6 | aksarka
# Processing Record 23 of Set 6 | vung tau
# Processing Record 24 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 6 | pachino
# Processing Record 26 of Set 6 | carutapera
# Processing Record 27 of Set 6 | faanui
# Processing Record 28 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 6 | sciacca
# Processing Record 30 of Set 6 | sinnamary
# Processing Record 31 of Set 6 | turukhansk
# Processing Record 32 of Set 6 | tual
# Processing Record 33 of Set 6 | saldanha
# Processing Record 34 of Set 6 | tuatapere
# Processing Record 35 of Set 6 | saint-prosper
# Processing Record 36 of Set 6 | castro
# Processing Record 37 of Set 6 | vredendal
# Processing Record 38 of Set 6 | hokitika
# Processing Record 39 of Set 6 | taoudenni
# Processing Record 40 of Set 6 | sassandra
# Processing Record 41 of Set 6 | knysna
# Processing Record 42 of Set 6 | richards bay
# Processing Record 43 of Set 6 | jaru
# Processing Record 44 of Set 6 | mae sai
# Processing Record 45 of Set 6 | abu dhabi
# Processing Record 46 of Set 6 | jumla
# Processing Record 47 of Set 6 | tshane
# Processing Record 48 of Set 6 | sakaiminato
# Processing Record 49 of Set 6 | pauini
# Processing Record 50 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 7 | vilhena
# Processing Record 2 of Set 7 | ginir
# Processing Record 3 of Set 7 | tabuk
# Processing Record 4 of Set 7 | hengyang
# Processing Record 5 of Set 7 | aswan
# Processing Record 6 of Set 7 | sola
# Processing Record 7 of Set 7 | jacksonville beach
# Processing Record 8 of Set 7 | bima
# Processing Record 9 of Set 7 | labuhan
# Processing Record 10 of Set 7 | kozmodemyansk
# Processing Record 11 of Set 7 | manggar
# Processing Record 12 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 7 | qiongshan
# Processing Record 14 of Set 7 | matara
# Processing Record 15 of Set 7 | almunecar
# Processing Record 16 of Set 7 | zolochiv
# Processing Record 17 of Set 7 | la cruz
# Processing Record 18 of Set 7 | quang ngai
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | san juan
# Processing Record 21 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 7 | chilliwack
# Processing Record 23 of Set 7 | tessalit
# Processing Record 24 of Set 7 | san jose
# Processing Record 25 of Set 7 | zyryanka
# Processing Record 26 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 7 | kaitangata
# Processing Record 28 of Set 7 | cairns
# Processing Record 29 of Set 7 | nizwa
# Processing Record 30 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 7 | selma
# Processing Record 32 of Set 7 | teya
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | dalhousie
# Processing Record 35 of Set 7 | axim
# Processing Record 36 of Set 7 | longkou
# Processing Record 37 of Set 7 | cockburn town
# Processing Record 38 of Set 7 | shaunavon
# Processing Record 39 of Set 7 | izumo
# Processing Record 40 of Set 7 | omsukchan
# Processing Record 41 of Set 7 | idappadi
# Processing Record 42 of Set 7 | chokurdakh
# Processing Record 43 of Set 7 | dzilam gonzalez
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | shibetsu
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | lapua
# Processing Record 48 of Set 7 | puerto escondido
# Processing Record 49 of Set 7 | necochea
# Processing Record 50 of Set 7 | aklavik
# Processing Record 1 of Set 8 | sao filipe
# Processing Record 2 of Set 8 | kalmunai
# Processing Record 3 of Set 8 | beloha
# Processing Record 4 of Set 8 | marsa matruh
# Processing Record 5 of Set 8 | heishan
# Processing Record 6 of Set 8 | tabou
# Processing Record 7 of Set 8 | nikel
# Processing Record 8 of Set 8 | green river
# Processing Record 9 of Set 8 | itoman
# Processing Record 10 of Set 8 | ahipara
# Processing Record 11 of Set 8 | tapes
# Processing Record 12 of Set 8 | raudeberg
# Processing Record 13 of Set 8 | laguna
# Processing Record 14 of Set 8 | conceicao do araguaia
# Processing Record 15 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 16 of Set 8 | torbay
# Processing Record 17 of Set 8 | arlit
# Processing Record 18 of Set 8 | marzuq
# Processing Record 19 of Set 8 | rocha
# Processing Record 20 of Set 8 | koumac
# Processing Record 21 of Set 8 | mareeba
# Processing Record 22 of Set 8 | yar-sale
# Processing Record 23 of Set 8 | grindavik
# Processing Record 24 of Set 8 | guangyuan
# Processing Record 25 of Set 8 | north bend
# Processing Record 26 of Set 8 | broken hill
# Processing Record 27 of Set 8 | golden gate
# Processing Record 28 of Set 8 | nantucket
# Processing Record 29 of Set 8 | wellington
# Processing Record 30 of Set 8 | male
# Processing Record 31 of Set 8 | victoria
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | qui nhon
# Processing Record 34 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 8 | skibbereen
# Processing Record 36 of Set 8 | pavlodar
# Processing Record 37 of Set 8 | biryusinsk
# Processing Record 38 of Set 8 | leh
# Processing Record 39 of Set 8 | betafo
# Processing Record 40 of Set 8 | dolores
# Processing Record 41 of Set 8 | ust-karsk
# Processing Record 42 of Set 8 | casablanca
# Processing Record 43 of Set 8 | ust-nera
# Processing Record 44 of Set 8 | plavsk
# Processing Record 45 of Set 8 | burns lake
# Processing Record 46 of Set 8 | yinchuan
# Processing Record 47 of Set 8 | port macquarie
# Processing Record 48 of Set 8 | wattegama
# Processing Record 49 of Set 8 | harper
# Processing Record 50 of Set 8 | areosa
# Processing Record 1 of Set 9 | dolinsk
# Processing Record 2 of Set 9 | airai
# Processing Record 3 of Set 9 | dingle
# Processing Record 4 of Set 9 | vila
# Processing Record 5 of Set 9 | nadym
# Processing Record 6 of Set 9 | buchanan
# Processing Record 7 of Set 9 | svetlyy
# Processing Record 8 of Set 9 | souillac
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | greenwood
# Processing Record 11 of Set 9 | chuy
# Processing Record 12 of Set 9 | krsko
# Processing Record 13 of Set 9 | saint-michel-des-saints
# Processing Record 14 of Set 9 | pyu
# Processing Record 15 of Set 9 | salinas
# Processing Record 16 of Set 9 | liaozhong
# Processing Record 17 of Set 9 | taltal
# Processing Record 18 of Set 9 | rovaniemi
# Processing Record 19 of Set 9 | kavieng
# Processing Record 20 of Set 9 | tchibanga
# Processing Record 21 of Set 9 | halden
# Processing Record 22 of Set 9 | coihaique
# Processing Record 23 of Set 9 | bone
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | buin
# Processing Record 26 of Set 9 | valparaiso
# Processing Record 27 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 28 of Set 9 | road town
# Processing Record 29 of Set 9 | kuytun
# Processing Record 30 of Set 9 | iracoubo
# Processing Record 31 of Set 9 | the valley
# Processing Record 32 of Set 9 | verkhoyansk
# Processing Record 33 of Set 9 | asau
# Processing Record 34 of Set 9 | buraydah
# Processing Record 35 of Set 9 | san ignacio
# Processing Record 36 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 9 | oktyabrskoye
# Processing Record 38 of Set 9 | fortuna
# Processing Record 39 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 9 | morehead
# Processing Record 41 of Set 9 | illela
# Processing Record 42 of Set 9 | san cristobal
# Processing Record 43 of Set 9 | visby
# Processing Record 44 of Set 9 | moissala
# Processing Record 45 of Set 9 | namatanai
# Processing Record 46 of Set 9 | piacabucu
# Processing Record 47 of Set 9 | novooleksiyivka
# Processing Record 48 of Set 9 | east wenatchee
# Processing Record 49 of Set 9 | debre zeyit
# Processing Record 50 of Set 9 | kapoeta
# Processing Record 1 of Set 10 | sunnyside
# Processing Record 2 of Set 10 | broome
# Processing Record 3 of Set 10 | skjervoy
# Processing Record 4 of Set 10 | redlands
# Processing Record 5 of Set 10 | belyy yar
# Processing Record 6 of Set 10 | waingapu
# Processing Record 7 of Set 10 | manakara
# Processing Record 8 of Set 10 | mugur-aksy
# Processing Record 9 of Set 10 | islampur
# Processing Record 10 of Set 10 | mersing
# Processing Record 11 of Set 10 | mujiayingzi
# Processing Record 12 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 10 | la asuncion
# Processing Record 14 of Set 10 | acara
# Processing Record 15 of Set 10 | hamilton
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | chara
# Processing Record 18 of Set 10 | puerto narino
# Processing Record 19 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 10 | xinqing
# Processing Record 21 of Set 10 | kundiawa
# Processing Record 22 of Set 10 | kochi
# Processing Record 23 of Set 10 | mezhdurechensk
# Processing Record 24 of Set 10 | oltu
# Processing Record 25 of Set 10 | west helena
# Processing Record 26 of Set 10 | maceio
# Processing Record 27 of Set 10 | tilichiki
# Processing Record 28 of Set 10 | marfino
# Processing Record 29 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 30 of Set 10 | vavuniya
# Processing Record 31 of Set 10 | sumenep
# Processing Record 32 of Set 10 | healdsburg
# Processing Record 33 of Set 10 | la ciotat
# Processing Record 34 of Set 10 | lokosovo
# Processing Record 35 of Set 10 | praya
# Processing Record 36 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 10 | ariano irpino
# Processing Record 38 of Set 10 | melioratorov
# Processing Record 39 of Set 10 | pangai
# Processing Record 40 of Set 10 | kaohsiung
# Processing Record 41 of Set 10 | parakai
# Processing Record 42 of Set 10 | sydney
# Processing Record 43 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 44 of Set 10 | new glasgow
# Processing Record 45 of Set 10 | lorengau
# Processing Record 46 of Set 10 | oranjestad
# Processing Record 47 of Set 10 | masterton
# Processing Record 48 of Set 10 | jega
# Processing Record 49 of Set 10 | bairnsdale
# Processing Record 50 of Set 10 | mount isa
# Processing Record 1 of Set 11 | hovd
# Processing Record 2 of Set 11 | sambava
# Processing Record 3 of Set 11 | fallon
# Processing Record 4 of Set 11 | poya
# Processing Record 5 of Set 11 | vestmannaeyjar
# Processing Record 6 of Set 11 | yenagoa
# Processing Record 7 of Set 11 | vargashi
# Processing Record 8 of Set 11 | kedrovyy
# Processing Record 9 of Set 11 | caraquet
# Processing Record 10 of Set 11 | morki
# Processing Record 11 of Set 11 | saint-paul
# Processing Record 12 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 13 of Set 11 | barabai
# Processing Record 14 of Set 11 | paka
# Processing Record 15 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 11 | suntar
# Processing Record 17 of Set 11 | inyonga
# Processing Record 18 of Set 11 | vao
# Processing Record 19 of Set 11 | boden
# Processing Record 20 of Set 11 | larap
# Processing Record 21 of Set 11 | port maria
# Processing Record 22 of Set 11 | camacha
# Processing Record 23 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 11 | esmeraldas
# Processing Record 25 of Set 11 | biak
# Processing Record 26 of Set 11 | rancho palos verdes
# Processing Record 27 of Set 11 | vardo
# Processing Record 28 of Set 11 | kalachinsk
# Processing Record 29 of Set 11 | narok
# Processing Record 30 of Set 11 | samarai
# Processing Record 31 of Set 11 | bereda
# Processing Record 32 of Set 11 | watsa
# Processing Record 33 of Set 11 | turka
# Processing Record 34 of Set 11 | ruston
# Processing Record 35 of Set 11 | senador jose porfirio
# Processing Record 36 of Set 11 | henties bay
# Processing Record 37 of Set 11 | benjamin hill
# Processing Record 38 of Set 11 | zharkent
# Processing Record 39 of Set 11 | henderson
# Processing Record 40 of Set 11 | camacupa
# Processing Record 41 of Set 11 | duz
# City not found. Skipping...
# Processing Record 42 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 43 of Set 11 | suhbaatar
# Processing Record 44 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 45 of Set 11 | krumbach
# Processing Record 46 of Set 11 | moindou
# Processing Record 47 of Set 11 | kangaatsiaq
# Processing Record 48 of Set 11 | kinkala
# Processing Record 49 of Set 11 | alta floresta
# Processing Record 50 of Set 11 | bud
# Processing Record 1 of Set 12 | malm
# Processing Record 2 of Set 12 | ayagoz
# Processing Record 3 of Set 12 | mezen
# Processing Record 4 of Set 12 | gannan
# Processing Record 5 of Set 12 | ndungu
# Processing Record 6 of Set 12 | oga
# Processing Record 7 of Set 12 | bontang
# Processing Record 8 of Set 12 | cap-aux-meules
# Processing Record 9 of Set 12 | nampula
# Processing Record 10 of Set 12 | pericos
# Processing Record 11 of Set 12 | alice springs
# Processing Record 12 of Set 12 | san patricio
# Processing Record 13 of Set 12 | pangkalanbuun
# Processing Record 14 of Set 12 | ilulissat
# Processing Record 15 of Set 12 | saint-augustin
# Processing Record 16 of Set 12 | sibolga
# Processing Record 17 of Set 12 | lagos
# Processing Record 18 of Set 12 | burica
# City not found. Skipping...
# Processing Record 19 of Set 12 | mackay
# Processing Record 20 of Set 12 | erenhot
# Processing Record 21 of Set 12 | praia da vitoria
# Processing Record 22 of Set 12 | kalianget
# Processing Record 23 of Set 12 | horsham
# Processing Record 24 of Set 12 | flinders
# Processing Record 25 of Set 12 | hita
# Processing Record 26 of Set 12 | olinda
# Processing Record 27 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 12 | parnarama
# Processing Record 29 of Set 12 | kolyvan
# Processing Record 30 of Set 12 | padang
# Processing Record 31 of Set 12 | ciudad guayana
# Processing Record 32 of Set 12 | lazaro cardenas
# Processing Record 33 of Set 12 | asfi
# Processing Record 34 of Set 12 | leninskoye
# Processing Record 35 of Set 12 | santa isabel
# Processing Record 36 of Set 12 | pemangkat
# Processing Record 37 of Set 12 | dzerzhinsk
# Processing Record 38 of Set 12 | gorkovskoye
# City not found. Skipping...
# Processing Record 39 of Set 12 | beringovskiy
# Processing Record 40 of Set 12 | muroto
# Processing Record 41 of Set 12 | novogurovskiy
# Processing Record 42 of Set 12 | coquimbo
# Processing Record 43 of Set 12 | touros
# Processing Record 44 of Set 12 | smithers
# Processing Record 45 of Set 12 | peniche
# Processing Record 46 of Set 12 | maldonado
# Processing Record 47 of Set 12 | aquiraz
# Processing Record 48 of Set 12 | manturovo
# Processing Record 49 of Set 12 | kuito
# Processing Record 50 of Set 12 | nalut
# Processing Record 1 of Set 13 | khvoynaya
# Processing Record 2 of Set 13 | cabo rojo
# Processing Record 3 of Set 13 | viransehir
# Processing Record 4 of Set 13 | cuenca
# Processing Record 5 of Set 13 | kaeo
# Processing Record 6 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 13 | grand-santi
# Processing Record 8 of Set 13 | shimoda
# Processing Record 9 of Set 13 | yulara
# Processing Record 10 of Set 13 | ternate
# Processing Record 11 of Set 13 | dunedin
# Processing Record 12 of Set 13 | stephenville
# Processing Record 13 of Set 13 | morondava
# Processing Record 14 of Set 13 | sept-iles
# Processing Record 15 of Set 13 | ottawa
# Processing Record 16 of Set 13 | ustye
# Processing Record 17 of Set 13 | korem
# Processing Record 18 of Set 13 | bekesszentandras
# Processing Record 19 of Set 13 | general pico
# Processing Record 20 of Set 13 | nizhneivkino
# Processing Record 21 of Set 13 | ketchikan
# Processing Record 22 of Set 13 | la tebaida
# Processing Record 23 of Set 13 | tukrah
# Processing Record 24 of Set 13 | lufilufi
# Processing Record 25 of Set 13 | gushikawa
# Processing Record 26 of Set 13 | ballina
# Processing Record 27 of Set 13 | staryy nadym
# Processing Record 28 of Set 13 | foumban
# Processing Record 29 of Set 13 | hendersonville
# Processing Record 30 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 13 | cintalapa
# Processing Record 32 of Set 13 | lindi
# Processing Record 33 of Set 13 | machilipatnam
# Processing Record 34 of Set 13 | kargasok
# Processing Record 35 of Set 13 | iqaluit
# Processing Record 36 of Set 13 | san andres
# Processing Record 37 of Set 13 | oriximina
# Processing Record 38 of Set 13 | burkhala
# City not found. Skipping...
# Processing Record 39 of Set 13 | altamira
# Processing Record 40 of Set 13 | alihe
# Processing Record 41 of Set 13 | riyadh
# Processing Record 42 of Set 13 | gilgit
# Processing Record 43 of Set 13 | tirumullaivasal
# Processing Record 44 of Set 13 | christchurch
# Processing Record 45 of Set 13 | trogir
# Processing Record 46 of Set 13 | singapore
# Processing Record 47 of Set 13 | takoradi
# Processing Record 48 of Set 13 | palmer
# Processing Record 49 of Set 13 | kokoda
# Processing Record 50 of Set 13 | celestun
# Processing Record 1 of Set 14 | iberia
# Processing Record 2 of Set 14 | egvekinot
# Processing Record 3 of Set 14 | narsaq
# Processing Record 4 of Set 14 | les cayes
# Processing Record 5 of Set 14 | ostersund
# Processing Record 6 of Set 14 | morant bay
# Processing Record 7 of Set 14 | seminole
# Processing Record 8 of Set 14 | semporna
# Processing Record 9 of Set 14 | sorland
# Processing Record 10 of Set 14 | kijang
# Processing Record 11 of Set 14 | iquique
# Processing Record 12 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 13 of Set 14 | pirovskoye
# Processing Record 14 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 14 | fort nelson
# Processing Record 16 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 17 of Set 14 | huarmey
# Processing Record 18 of Set 14 | oistins
# Processing Record 19 of Set 14 | starotimoshkino
# Processing Record 20 of Set 14 | touho
# Processing Record 21 of Set 14 | xique-xique
# Processing Record 22 of Set 14 | inhambane
# Processing Record 23 of Set 14 | key west
# Processing Record 24 of Set 14 | dicabisagan
# Processing Record 25 of Set 14 | lebanon
# Processing Record 26 of Set 14 | pavlovskiy posad
# Processing Record 27 of Set 14 | paso de carrasco
# Processing Record 28 of Set 14 | ures
# Processing Record 29 of Set 14 | reconquista
# Processing Record 30 of Set 14 | prainha
# Processing Record 31 of Set 14 | muros
# Processing Record 32 of Set 14 | udachnyy
# Processing Record 33 of Set 14 | lasa
# Processing Record 34 of Set 14 | machiques
# Processing Record 35 of Set 14 | waipawa
# Processing Record 36 of Set 14 | mumford
# Processing Record 37 of Set 14 | kathu
# Processing Record 38 of Set 14 | matagami
# Processing Record 39 of Set 14 | khandagayty
# Processing Record 40 of Set 14 | inirida
# Processing Record 41 of Set 14 | sault sainte marie
# Processing Record 42 of Set 14 | ugoofaaru
# Processing Record 43 of Set 14 | januaria
# Processing Record 44 of Set 14 | chapada dos guimaraes
# Processing Record 45 of Set 14 | aleppo
# Processing Record 46 of Set 14 | hualmay
# Processing Record 47 of Set 14 | south venice
# Processing Record 48 of Set 14 | srednekolymsk
# Processing Record 49 of Set 14 | strezhevoy
# Processing Record 50 of Set 14 | sobolevo
# Processing Record 1 of Set 15 | port hawkesbury
# Processing Record 2 of Set 15 | xochistlahuaca
# Processing Record 3 of Set 15 | porterville
# Processing Record 4 of Set 15 | port lincoln
# Processing Record 5 of Set 15 | asahi
# Processing Record 6 of Set 15 | yzeure
# Processing Record 7 of Set 15 | mozarlandia
# Processing Record 8 of Set 15 | shirgaon
# Processing Record 9 of Set 15 | kortkeros
# Processing Record 10 of Set 15 | manavalakurichi
# Processing Record 11 of Set 15 | ames
# Processing Record 12 of Set 15 | santiago del estero
# Processing Record 13 of Set 15 | lovozero
# Processing Record 14 of Set 15 | biggar
# Processing Record 15 of Set 15 | san matias
# Processing Record 16 of Set 15 | weatherford
# Processing Record 17 of Set 15 | ambilobe
# Processing Record 18 of Set 15 | neiafu
# Processing Record 19 of Set 15 | port hardy
# Processing Record 20 of Set 15 | kez
# Processing Record 21 of Set 15 | babugarh
# Processing Record 22 of Set 15 | cody
# Processing Record 23 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 15 | navalmoral de la mata
# Processing Record 25 of Set 15 | belmonte
# Processing Record 26 of Set 15 | aksu
# Processing Record 27 of Set 15 | paragominas
# Processing Record 28 of Set 15 | hofn
# Processing Record 29 of Set 15 | teguldet
# Processing Record 30 of Set 15 | oxbow
# Processing Record 31 of Set 15 | shumskiy
# Processing Record 32 of Set 15 | tezu
# Processing Record 33 of Set 15 | yajalon
# Processing Record 34 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 15 | nouakchott
# Processing Record 36 of Set 15 | rabapatona
# Processing Record 37 of Set 15 | talcahuano
# Processing Record 38 of Set 15 | sunrise manor
# Processing Record 39 of Set 15 | grand forks
# Processing Record 40 of Set 15 | chibuto
# Processing Record 41 of Set 15 | kanniyakumari
# Processing Record 42 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 43 of Set 15 | biu
# Processing Record 44 of Set 15 | batemans bay
# Processing Record 45 of Set 15 | aripuana
# Processing Record 46 of Set 15 | sinazongwe
# Processing Record 47 of Set 15 | onguday
# Processing Record 48 of Set 15 | paita
# Processing Record 49 of Set 15 | key largo
# Processing Record 50 of Set 15 | las choapas
# Processing Record 1 of Set 16 | clyde
# Processing Record 2 of Set 16 | dhidhdhoo
# Processing Record 3 of Set 16 | whitehorse
# Processing Record 4 of Set 16 | tarnogskiy gorodok
# Processing Record 5 of Set 16 | yarkovo
# Processing Record 6 of Set 16 | havoysund
# Processing Record 7 of Set 16 | letenye
# Processing Record 8 of Set 16 | lubumbashi
# Processing Record 9 of Set 16 | manzil salim
# Processing Record 10 of Set 16 | qaqortoq
# Processing Record 11 of Set 16 | khasan
# Processing Record 12 of Set 16 | burla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Havelock      US  34.8791  -76.9013     88.05        80
# 1             Hithadhoo      MV  -0.6000   73.0833     81.54        73
# 2                Bethel      US  41.3712  -73.4140     73.85        89
# 3                  Hami      CN  42.8000   93.4500     79.72        22
# 4          Puerto Ayora      EC  -0.7393  -90.3518     80.56        81
# 5              Cidreira      BR -30.1811  -50.2056     65.84        76
# 6  Vila Franca Do Campo      PT  37.7167  -25.4333     70.21        80
# 7               Ushuaia      AR -54.8000  -68.3000     35.26        80
# 8               Salalah      OM  17.0151   54.0924     78.87        88
# 9                 Bluff      NZ -46.6000  168.3333     42.76        80
#
#    Cloudiness  Wind Speed Current Description
# 0         100        5.01     overcast clouds
# 1          12        4.25          few clouds
# 2          91        7.85     overcast clouds
# 3           0        4.92           clear sky
# 4          50        9.84    scattered clouds
# 5         100        2.66     overcast clouds
# 6          54        8.70       broken clouds
# 7          75        6.91       broken clouds
# 8         100        5.12     overcast clouds
# 9          97       17.54     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
